# %%
import json
from pprint import pprint
N = 1000000

# %%
w = []
with open('') as data_file: 
    for x in xrange(N):
        data = next(data_file).decode('utf-8')
        data_json = json.loads(data)
        # (data_json['name'].lower().find(u'data ') > -1) and 
        # and (data_json['description'].lower().find(u'мфти') > -1)
        if (data_json['name'].lower().find(u'категорий') > -1) and  (data_json['area']['name'].lower().find(u'москва') > -1) :
            w.append(data_json)
            if data_json['salary'] is not None:
                print data_json['employer']['name'], data_json['name'], data_json['salary']['from'], data_json['salary']['to']
# Out:
# Приват Трэйд (KupiVip) Категорийный менеджер по закупкам (косметика/парфюмерия) 100000 None
# ААА Групп
#  Менеджер по закупкам / Категорийный менеджер 35000 50000
# Детские Товары Оптом
#  Ассистент категорийного менеджера 30000 35000
# Связной
#  Начальник отдела портативной электроники (Руководитель группы категорийных менеджеров/продакт менеджеров) None 125000
# Афоничкина О.И.
#  Ассистент категорийного менеджера 40000 None
# Фирма БиМ
#  Категорийный менеджер 45000 45000
# МФК-профит
#  Бренд-менеджер/категорийный менеджер 60000 None
# Объединение Стройкомплект
#  Категорийный менеджер (непродовольственные товары) 100000 None
# РУСДЕЛ
#  Ассистент категорийного менеджера 40000 45000
# Enter
#  Категорийный менеджер проекта Tchibo None 100000
# Фан-спорт
#  Категорийный менеджер (спорттовары) 40000 50000
# АЛМИ, Сеть магазинов
#  Категорийный менеджер/менеджер по закупкам 70000 None
# Оптима
#  Менеджер по закупкам цифровой техники / Категорийный менеджер 80000 120000
# ...

# %%
for x in w[0].keys():
    print x
    print
# Out:
# code
#
# site
#
# published_at
#
# accept_handicapped
#
# alternate_url
#
# key_skills
#
# employment
#
# id
#
# archived
#
# contacts
#
# response_url
#
# relations
#
# employer
#
# response_letter_required
#
# test
#
# hidden
#
# type
#
# specializations
#
# premium
#
# description
#
# schedule
#
# suitable_resumes_url
#
# billing_type
#
# department
#
# allow_messages
#
# address
#
# salary
#
# apply_alternate_url
#
# name
#
# created_at
#
# area
#
# experience
#
# negotiations_url
#
# branded_description

# %%
for x in w:
    print x['area']['name']
# Out:
# Москва
# Москва
# Нижний Новгород
# Нижний Новгород
# Москва
# Липецк
# Краснодар
# Кострома
# Ярославль
# Москва
